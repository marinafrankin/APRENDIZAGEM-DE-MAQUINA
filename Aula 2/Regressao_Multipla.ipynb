# %% [markdown]
# ### Regressão Multipa

# %%
import numpy as np

dados = np.genfromtxt('kc_house_data.csv', delimiter=',', skip_header=1, usecols=(2, 3, 4, 5))
dados = np.char.strip(dados, '""').astype(float)

y = dados[:, 0]
X_features = dados[:, 1:]

m = X_features.shape[0]
X = np.c_[np.ones(m), X_features]

X_T = X.T

beta = np.linalg.inv(X_T @ X) @ X_T @ y

print("=== Coeficientes Descobertos ===")
print(f"Intercepto (Base 0): {beta[0]:.2f}")
print(f"Peso para Quartos (Base 1): {beta[1]:.2f}")
print(f"Peso para Banheiros (Base 2): {beta[2]:.2f}")
print(f"Peso para Área/sqft (Base 3): {beta[3]:.2f}\n")

casa_teste = np.array([1, 3, 1, 1180])
preco_previsto = casa_teste @ beta

print("=== Teste de Previsão ===")
print(f"Preço REAL da casa 1: $ {y[0]:.2f}")
print(f"Preço PREVISTO pelo nosso modelo: $ {preco_previsto:.2f}")
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       2
#       3 dados = np.genfromtxt('kc_house_data.csv', delimiter=',', skip_header=1, usecols=(2, 3, 4, 5))
# ----> 4 dados = np.char.strip(dados, '""').astype(float)
#       5
#       6 y = dados[:, 0:]
#       7 X_features = dados[:, 1:]
#
# File c:\dev\py\Lib\site-packages\numpy\_core\strings.py:1077, in strip(a, chars)
#    1075 if chars is None:
#    1076     return _strip_whitespace(a)
# -> 1077 return _strip_chars(a, chars)
#
# UFuncTypeError: ufunc '_strip_chars' did not contain a loop with signature matching types (<class 'numpy.dtypes.Float64DType'>, <class 'numpy.dtypes.StrDType'>) -> None
